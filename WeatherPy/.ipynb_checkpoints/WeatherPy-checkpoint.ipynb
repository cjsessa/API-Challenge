# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "..Instructions/output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key +"&q="

city_data=[]
record_count=1
set_count=1

print("beginning data retrival")
print('-----------------------')

for i,city in enumerate(cities):
    
    if(i%50==0 and i>=50):
        record_count=1
        set_count+=1
        
    print(f'processing record {record_count} of set {set_count} | {city}')
    record_count+=1
    response = requests.get(url+city).json()
    try:
        city_data.append({
            "City": city,
            "Lat": response['coord']['lat'],
            'Lon': response['coord']['lon'],
            'Max Temp': response['main']['temp_max'],
            'Humidity': response['main']['humidity'],
            'Cloudiness': response['clouds']['all'],
            'Wind Speed': response['wind']['speed'],
            'Country': response['sys']['country'],
            'Date': response['dt']
        })
    except:
        print('City not found. Skipping...')
        pass
print('------------------------')
print('Data retrieval completed')
print('------------------------')
# Out:
# beginning data retrival
# -----------------------
# processing record 1 of set 1 | tiksi
# processing record 2 of set 1 | solnechnyy
# processing record 3 of set 1 | muscle shoals
# processing record 4 of set 1 | barrow
# processing record 5 of set 1 | atuona
# processing record 6 of set 1 | mar del plata
# processing record 7 of set 1 | ilulissat
# processing record 8 of set 1 | rikitea
# processing record 9 of set 1 | hilo
# processing record 10 of set 1 | hermanus
# processing record 11 of set 1 | ushuaia
# processing record 12 of set 1 | illoqqortoormiut
# City not found. Skipping...
# processing record 13 of set 1 | yialos
# City not found. Skipping...
# processing record 14 of set 1 | vostok
# processing record 15 of set 1 | kirando
# processing record 16 of set 1 | la ronge
# processing record 17 of set 1 | rongcheng
# processing record 18 of set 1 | dunda
# processing record 19 of set 1 | hamilton
# processing record 20 of set 1 | spirit river
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(city_data)

df1= df[['City','Cloudiness','Country','Date',
        'Humidity','Lat','Lon','Max Temp','Wind Speed']].rename(
        columns = {'Lon' : 'Lng'})

df1.to_csv('cities.csv',index=True)
df1.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          tiksi          74      RU  1581469911        85  71.69  128.87
# 1     solnechnyy          34      RU  1581469911        93  50.72  136.63
# 2  muscle shoals          90      US  1581469911        93  34.74  -87.67
# 3         barrow           1      US  1581469911        74  71.29 -156.79
# 4         atuona           0      PF  1581469831        76  -9.80 -139.03
#
#    Max Temp  Wind Speed
# 0    -22.43        3.69
# 1      8.71        1.12
# 2     46.99        4.70
# 3    -23.80        6.93
# 4     81.54       13.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.title('City Latitude vs. Max Temperature (1/26/20)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (Fahrenheit)')

x =df1['Lat']
plt.grid(color = 'lightgrey', linestyle = '-',linewidth = .5)
plt.scatter(x,df1['Max Temp'], color = 'steelblue', marker = 'o', linestyle = 'dashed',
           linewidth = 1, ec = 'black')
plt.savefig('../output_data/lat_vs_temp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.title('City Latitude vs. Humidity (1/26/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')

x =df1['Lat']
plt.grid(color = 'lightgrey', linestyle = '-',linewidth = .5)
plt.scatter(x,df1['Humidity'], color = 'steelblue', marker = 'o', linestyle = 'dashed',
           linewidth = 1, ec = 'black')
plt.savefig('../output_data/lat_vs_hum.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.title('City Latitude vs. Cloudiness % (1/26/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')

x =df1['Lat']
plt.grid(color = 'lightgrey', linestyle = '-',linewidth = .5)
plt.scatter(x,df1['Cloudiness'], color = 'steelblue', marker = 'o', linestyle = 'dashed',
           linewidth = 1, ec = 'black')
plt.savefig('../output_data/lat_vs_cloud.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.title('City Latitude vs. Wind Speed (mph) (1/26/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

x =df1['Lat']
plt.grid(color = 'lightgrey', linestyle = '-',linewidth = .5)
plt.scatter(x,df1['Wind Speed'], color = 'steelblue', marker = 'o', linestyle = 'dashed',
           linewidth = 1, ec = 'black')

plt.savefig('../output_data/lat_vs_windsp.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# st

# %%
# Create Northern and Southern Hemisphere DataFrames
#getting north hemisphere
n_hemi= df1.loc[df1['Lat'] >= 0]
n_hemi['Hemisphere'] = 'North'

#getting south hemisphere
s_hemi = df1.loc[df1['Lat'] < 0]
s_hemi['Hemisphere'] = 'South'

n_hemi
# Out:
# C:\Users\adfil\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\adfil\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            tiksi          74      RU  1581469911        85  71.69  128.87
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setting x and y
x =n_hemi['Lat']
y = n_hemi['Max Temp']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#formatting equation
r = round(r_value,2)
p = round(p_value,4)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(0,-30), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (Fahrenheit)')
plt.scatter(x,y, color = 'steelblue', marker = 'o')

print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a negative relationship between')
print('Temperature and latitude. This means as you increase latitude, the temperature decreases')
print('The rate at which this decreases is 1.35 degrees F for each degree increase in latitude')
print('The p-value is close to zero, this means our coefficient of 1.35')
print('is highly significant and likely to occur')

plt.savefig('../output_data/n_reg.png')
plt.show()
# Out:
# The p-value is 0.0
# The r-squared is -0.87
# The linear regression shows that there is a negative relationship between
# Temperature and latitude. This means as you increase latitude, the temperature decreases
# The rate at which this decreases is 1.35 degrees F for each degree increase in latitude
# The p-value is close to zero, this means our coefficient of 1.35
# is highly significant and likely to occur

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setting x and y
x =s_hemi['Lat']
y = s_hemi['Max Temp']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
r = round(r_value,2)
p = round(p_value,4)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(-30,50), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.scatter(x,y, color = 'steelblue', marker = 'o')


print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('Temperature and latitude. This means as you increase latitude, the temperature increases')
print('The rate at which this increases is .28 degrees F for each degree increase in latitude')
print('The p-value is close to zero, this means our coefficient of .28')
print('is highly significant and likely to occur')
print('However, our r-square value is very low at .39 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .28, but')
print('this rate is not a good representation of the relationship')

plt.savefig('../output_data/s_reg.png')
plt.show()
# Out:
# The p-value is 0.0
# The r-squared is 0.39
# The linear regression shows that there is a positive relationship between
# Temperature and latitude. This means as you increase latitude, the temperature increases
# The rate at which this increases is .28 degrees F for each degree increase in latitude
# The p-value is close to zero, this means our coefficient of .28
# is highly significant and likely to occur
# However, our r-square value is very low at .39 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .28, but
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setting x and y
x =n_hemi['Lat']
y = n_hemi['Humidity']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(30,20), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.scatter(x,y, color = 'steelblue', marker = 'o')

print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('humidity percentage and latitude. This means as you increase latitude, the humidity increases')
print('The rate at which this increases is .25 percentage points of humidity for each degree increase in latitude')
print('The p-value is close to zero, this means our coefficient of .24')
print('is highly significant and likely to occur')
print('However, our r-square value is very low at .24 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .24, but')
print('this rate is not a good representation of the relationship')

plt.savefig('../output_data/n_reg_hum.png')
plt.show()
# Out:
# The p-value is 0.0
# The r-squared is 0.24
# The linear regression shows that there is a positive relationship between
# humidity percentage and latitude. This means as you increase latitude, the humidity increases
# The rate at which this increases is .25 percentage points of humidity for each degree increase in latitude
# The p-value is close to zero, this means our coefficient of .24
# is highly significant and likely to occur
# However, our r-square value is very low at .24 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .24, but
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setting x and y
x =s_hemi['Lat']
y = s_hemi['Humidity']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(-30,25), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.scatter(x,y, color = 'steelblue', marker = 'o')

print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('humidity percentage and latitude. This means as you increase latitude, the humidity increases')
print('The rate at which this increases is .17 percentage points of humidity for each degree increase in latitude')
print('The p-value is close to zero, this means our coefficient of .17')
print('is highly significant and likely to occur, with 95% confidience')
print('However, our r-square value is very low at .15 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .24, but')
print('this rate is not a good representation of the relationship')
plt.savefig('../output_data/s_reg_hum.png')
plt.show()
# Out:
# The p-value is 0.0594
# The r-squared is 0.15
# The linear regression shows that there is a positive relationship between
# humidity percentage and latitude. This means as you increase latitude, the humidity increases
# The rate at which this increases is .17 percentage points of humidity for each degree increase in latitude
# The p-value is close to zero, this means our coefficient of .17
# is highly significant and likely to occur, with 95% confidience
# However, our r-square value is very low at .15 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .24, but
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setting x and y
x =n_hemi['Lat']
y = n_hemi['Cloudiness']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(33,23), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Northern Hemisphere - Cloudieness(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.scatter(x,y, color = 'steelblue', marker = 'o')

print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('Cloudiness percentage and latitude. This means as you increase latitude, the cloudiness increases')
print('The rate at which this increases is .55 percentage points of cloudiness for each degree increase in latitude')
print('The p-value is close to zero, this means our coefficient of .55')
print('is highly significant and likely to occur')
print('However, our r-square value is very low at .28 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .55, but')
print('this rate is not a good representation of the relationship')
plt.savefig('../output_data/n_cloud.png')
plt.show()
# Out:
# The p-value is 0.0
# The r-squared is 0.28
# The linear regression shows that there is a positive relationship between
# Cloudiness percentage and latitude. This means as you increase latitude, the cloudiness increases
# The rate at which this increases is .55 percentage points of cloudiness for each degree increase in latitude
# The p-value is close to zero, this means our coefficient of .55
# is highly significant and likely to occur
# However, our r-square value is very low at .28 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .55, but
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setting x and y
x =s_hemi['Lat']
y = s_hemi['Cloudiness']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(-30,22), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Southern Hemisphere - Cloudieness(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.scatter(x,y, color = 'steelblue', marker = 'o')


print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('Cloudiness percentage and latitude. This means as you increase latitude, the cloudiness increases')
print('The rate at which this increases is .55 percentage points of cloudiness for each degree increase in latitude')
print('The p-value is .13, this means our coefficient of .34')
print('is unlikely to occur if we were to draw another sample.')
print('Also, our r-square value is very low at .12 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .34, but')
print('this rate is not a good representation of the relationship')
plt.savefig('../output_data/s_cloud.png')
plt.show()
# Out:
# The p-value is 0.1329
# The r-squared is 0.12
# The linear regression shows that there is a positive relationship between
# Cloudiness percentage and latitude. This means as you increase latitude, the cloudiness increases
# The rate at which this increases is .55 percentage points of cloudiness for each degree increase in latitude
# The p-value is .13, this means our coefficient of .34
# is unlikely to occur if we were to draw another sample.
# Also, our r-square value is very low at .12 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .34, but
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setting x and y
x =n_hemi['Lat']
y = n_hemi['Wind Speed']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(0,30), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Northern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.scatter(x,y, color = 'steelblue', marker = 'o')


print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a positive relationship between')
print('Wind speed (MPH) and latitude. This means as you increase latitude, the wind speed increases')
print('The rate at which this increases is .01 mph for each degree increase in latitude')
print('The p-value is .66, this means our coefficient of .01')
print('is highly  unlikely to occur')
print('Also, our r-square value is very low at .28 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is unlikely to be .55, and')
print('this rate is not a good representation of the relationship')
plt.savefig('../output_data/n_wind.png')
plt.show()
# Out:
# The p-value is 0.6556
# The r-squared is 0.02
# The linear regression shows that there is a positive relationship between
# Wind speed (MPH) and latitude. This means as you increase latitude, the wind speed increases
# The rate at which this increases is .01 mph for each degree increase in latitude
# The p-value is .66, this means our coefficient of .01
# is highly  unlikely to occur
# Also, our r-square value is very low at .28 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is unlikely to be .55, and
# this rate is not a good representation of the relationship

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setting x and y
x =s_hemi['Lat']
y = s_hemi['Wind Speed']

#regression
slope,intercept, r_value, p_value, std_err = st.linregress(x,y)

#checking r square value against pearson coefficient
p = round(p_value,4)
r = round(r_value,2)
slope = round(slope,2)
intercept = round(intercept,2)

#creating text for equation for graph
line_eq = "y = " + str(slope) + "x +"+ str(intercept) + ' + e'

#creating regression values for best fit line
regress_values = x*slope + intercept

#creating line of best fit and where to put line equation
plt.plot(x,regress_values,'r-')
plt.annotate(line_eq,(-40,27), fontsize = 16,color = 'red')


#labels/formats for plot
plt.title('Southern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.scatter(x,y, color = 'steelblue', marker = 'o')


print('The p-value is ' + str(p))
print('The r-squared is ' + str(r))
print('The linear regression shows that there is a negative relationship between')
print('Wind speed (MPH) and latitude. This means as you increase latitude, the wind speed decreases')
print('The rate at which this decreases is .09 mph for each degree increase in latitude')
print('The p-value is .008, this means our coefficient of .01')
print('is highly likely to occur, with 99% confidence')
print('Also, our r-square value is very low at -.2 which means that there is a lot of error in our model')
print('Together, this means that based on our sample, the rate of change is likely to be .09, but')
print('this rate is not a good representation of the relationship')
plt.savefig('../output_data/s_wind.png')
plt.show()
# Out:
# The p-value is 0.008
# The r-squared is -0.2
# The linear regression shows that there is a negative relationship between
# Wind speed (MPH) and latitude. This means as you increase latitude, the wind speed decreases
# The rate at which this decreases is .09 mph for each degree increase in latitude
# The p-value is .008, this means our coefficient of .01
# is highly likely to occur, with 99% confidence
# Also, our r-square value is very low at -.2 which means that there is a lot of error in our model
# Together, this means that based on our sample, the rate of change is likely to be .09, but
# this rate is not a good representation of the relationship
